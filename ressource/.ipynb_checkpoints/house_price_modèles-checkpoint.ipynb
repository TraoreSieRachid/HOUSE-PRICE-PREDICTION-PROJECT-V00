# %% [markdown]
# <h1 style="text-align:center;color:blue;font-size:30px;font-family:times">Ecole Nationale de la Statistique et de l'Analyse Economique Pierre NDIAYE (ENSAE)</h1><br>

# %% [markdown]
# <h1 style="text-align:center;color:yellow;font-size:50px;font-family:ALGERIAN;border:solid">Projet de Machine Learning</h1>

# %% [markdown]
# <h1 style="text-align:center;color:brown;font-size:50px;font-family:ALGERIAN;border:solid">House prices prediction</h1>

# %% [markdown]
# <div style="display:flex;text-align:justify">
#
#
# <ul style="text-align:justify;font-family:times;font-size:15px;list-style-type:circle; width:60%">
# <span style="font-weight:bold">Réalisé par </span>
#     <ul style="text-align:justify;font-family:times;font-size:15px;list-style-type:circle">
#         <li>Traoré sié rachid</li>
#         <li>Sarr el hadj mum</li>
#         <li>Traoré sié rachid</li>
#         <li>Sarr el hadj mum</li>
#     </ul>
#     <span style="font-style: italic;font-size:13px">Élèves Ingénieurs Statisticiens Economistes</span>
# </ul>
#
# <ul style="text-align:justify;font-family:times;font-size:15px;list-style-type:none;width:39%">
#  <li style="font-weight:bold">Sous la supervision de:</li>
#  <li>Mme Mously Diaw</li>
#     <span style="font-style: italic;font-size:13px">Senior Machine learning Engineer, Entrepreneure @Sen-IA
#     </span>
#
# </ul>
#
# </div>

# %% [markdown]
# > <p style="text-align:justify;font-family:times;font-size:18px;font-style: italic;font-family:Century Schoolbook">
#    La structure du projet est bien définie dans le fichier Readme. Notre objectif ici est de réaliser des essais de modèles allant d'une regression multiple aux méthodes ensemblistes en passant par une régularisation en particulier ridge.</p>

# %% [markdown]
# <h1 style="text-align:center;color:yellow;font-size:50px;font-family:ALGERIAN;border:solid">ESSAIS DE MODELES</h1>

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn import metrics
import joblib

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, OneHotEncoder

from sklearn.linear_model import LinearRegression, Ridge, Lasso,ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, VotingRegressor, StackingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
import lightgbm as lgb
from yellowbrick.regressor import ResidualsPlot
import missingno as msno

# %%
train_df = pd.read_csv("../data/train_df_labelled.csv")

# %%
train_df.head()
# Out:
#                             Type de logement    Zonage (Classification)  \
# 0               2 ÉTAGES 1946 ET PLUS RÉCENT  Résidentiel basse densité
# 1  1 ÉTAGE 1946 ET PLUS RÉCENT - TOUS STYLES  Résidentiel basse densité
# 2               2 ÉTAGES 1946 ET PLUS RÉCENT  Résidentiel basse densité
# 3               2 ÉTAGES 1945 ET PLUS ANCIEN  Résidentiel basse densité
# 4               2 ÉTAGES 1946 ET PLUS RÉCENT  Résidentiel basse densité
#
#    Façade (en pieds)  Superficie du lot (pieds²) Type de route  \
# 0               65.0                        8450          Pavé
# 1               80.0                        9600          Pavé
# 2               68.0                       11250          Pavé
# 3               60.0                        9550          Pavé
# 4               84.0                       14260          Pavé
#
#             Forme du lot Topographie du terrain  \
# 0               Régulier            Plat/Niveau
# 1               Régulier            Plat/Niveau
# 2  Légèrement irrégulier            Plat/Niveau
# 3  Légèrement irrégulier            Plat/Niveau
# 4  Légèrement irrégulier            Plat/Niveau
#
#                         Services publics disponibles Configuration du lot  \
# 0  Tous les services publics (Électricité, Gaz, E...        Lot intérieur
# 1  Tous les services publics (Électricité, Gaz, E...        Double façade
# 2  Tous les services publics (Électricité, Gaz, E...        Lot intérieur
# 3  Tous les services publics (Électricité, Gaz, E...          Lot d'angle
# 4  Tous les services publics (Électricité, Gaz, E...        Double façade
#
#   Inclinaison du terrain  ... Mois de vente                     Type de vente  \
# 0            Pente douce  ...       Février  Acte de garantie - Conventionnel
# 1            Pente douce  ...           Mai  Acte de garantie - Conventionnel
# 2            Pente douce  ...     Septembre  Acte de garantie - Conventionnel
# 3            Pente douce  ...       Février  Acte de garantie - Conventionnel
# 4            Pente douce  ...      Décembre  Acte de garantie - Conventionnel
#
#   Condition de la vente Prix de vente Âge de la maison  \
# 0         Vente normale     12.247699                5
# 1         Vente normale     12.109016               31
# 2         Vente normale     12.317171                7
# 3        Vente anormale     11.849405               91
# 4         Vente normale     12.429220                8
#
#   Rénovation de la maison Surface totale (pieds²) Surface totale  \
# 0                       5                    2416           2566
# 1                      31                    2240           2524
# 2                       6                    2272           2706
# 3                      36                    1933           2473
# 4                       8                    2853           3343
#
#   Total des salles de bain Surface totale des porches (pieds²)
# 0                      3.5                                  61
# 1                      2.5                                 298
# 2                      3.5                                  42
# 3                      2.0                                 307
# 4                      3.5                                 276
#
# [5 rows x 60 columns]

# %%
train_df.columns
# Out:
# Index(['Type de logement', 'Zonage (Classification)', 'Façade (en pieds)',
#        'Superficie du lot (pieds²)', 'Type de route', 'Forme du lot',
#        'Topographie du terrain', 'Services publics disponibles',
#        'Configuration du lot', 'Inclinaison du terrain', 'Quartier',
#        'Proximité (1ère condition)', 'Proximité (2e condition)',
#        'Type de bâtiment', 'Style de maison', 'Qualité globale',
#        'État général', 'Style de toit', 'Matériau du toit',
#        'Revêtement extérieur (1)', 'Revêtement extérieur (2)',
#        'Type de parement en maçonnerie', 'Surface de parement (pieds²)',
#        'Qualité extérieure', 'État extérieur', 'Type de fondation',
#        'Qualité du sous-sol', 'État général du sous-sol',
#        'Exposition du sous-sol', 'Type de finition sous-sol (1)',
#        'Surface non finie sous-sol', 'Type de chauffage',
#        'Qualité du chauffage', 'Climatisation centrale', 'Système électrique',
#        'Surface finie basse qualité (pieds²)', 'Chambres (hors sous-sol)',
#        'Cuisines (hors sous-sol)', 'Qualité de la cuisine',
#        'Total des pièces (hors sous-sol)', 'Fonctionnalité globale',
#        'Nombre de cheminées', 'Qualité de la cheminée', 'Type de garage',
#        'Finition intérieure du garage', 'Capacité du garage (voitures)',
#        'Qualité du garage', 'Allée pavée', 'Surface de la piscine (pieds²)',
#        'Valeur des caractéristiques supplémentaires', 'Mois de vente',
#        'Type de vente', 'Condition de la vente', 'Prix de vente',
#        'Âge de la maison', 'Rénovation de la maison',
#        'Surface totale (pieds²)', 'Surface totale', 'Total des salles de bain',
#        'Surface totale des porches (pieds²)'],
#       dtype='object')

# %%
train_df.select_dtypes("object")
# Out:
#                                Type de logement    Zonage (Classification)  \
# 0                  2 ÉTAGES 1946 ET PLUS RÉCENT  Résidentiel basse densité
# 1     1 ÉTAGE 1946 ET PLUS RÉCENT - TOUS STYLES  Résidentiel basse densité
# 2                  2 ÉTAGES 1946 ET PLUS RÉCENT  Résidentiel basse densité
# 3                  2 ÉTAGES 1945 ET PLUS ANCIEN  Résidentiel basse densité
# 4                  2 ÉTAGES 1946 ET PLUS RÉCENT  Résidentiel basse densité
# ...                                         ...                        ...
# 1434               2 ÉTAGES 1946 ET PLUS RÉCENT  Résidentiel basse densité
# 1435  1 ÉTAGE 1946 ET PLUS RÉCENT - TOUS STYLES  Résidentiel basse densité
# 1436               2 ÉTAGES 1945 ET PLUS ANCIEN  Résidentiel basse densité
# 1437  1 ÉTAGE 1946 ET PLUS RÉCENT - TOUS STYLES  Résidentiel basse densité
# 1438  1 ÉTAGE 1946 ET PLUS RÉCENT - TOUS STYLES  Résidentiel basse densité
#
#      Type de route           Forme du lot Topographie du terrain  \
# 0             Pavé               Régulier            Plat/Niveau
# 1             Pavé               Régulier            Plat/Niveau
# 2             Pavé  Légèrement irrégulier            Plat/Niveau
# 3             Pavé  Légèrement irrégulier            Plat/Niveau
# 4             Pavé  Légèrement irrégulier            Plat/Niveau
# ...            ...                    ...                    ...
# 1434          Pavé               Régulier            Plat/Niveau
# 1435          Pavé               Régulier            Plat/Niveau
# 1436          Pavé               Régulier            Plat/Niveau
# 1437          Pavé               Régulier            Plat/Niveau
# 1438          Pavé               Régulier            Plat/Niveau
#
#                            Services publics disponibles Configuration du lot  \
# 0     Tous les services publics (Électricité, Gaz, E...        Lot intérieur
# 1     Tous les services publics (Électricité, Gaz, E...        Double façade
# 2     Tous les services publics (Électricité, Gaz, E...        Lot intérieur
# 3     Tous les services publics (Électricité, Gaz, E...          Lot d'angle
# 4     Tous les services publics (Électricité, Gaz, E...        Double façade
# ...                                                 ...                  ...
# 1434  Tous les services publics (Électricité, Gaz, E...        Lot intérieur
# 1435  Tous les services publics (Électricité, Gaz, E...        Lot intérieur
# 1436  Tous les services publics (Électricité, Gaz, E...        Lot intérieur
# 1437  Tous les services publics (Électricité, Gaz, E...        Lot intérieur
# 1438  Tous les services publics (Électricité, Gaz, E...        Lot intérieur
#
#      Inclinaison du terrain        Quartier     Proximité (1ère condition)  \
# 0               Pente douce   College Creek                        Normale
# 1               Pente douce         Veenker  Proche d'une route secondaire
# 2               Pente douce   College Creek                        Normale
# 3               Pente douce        Crawford                        Normale
# 4               Pente douce      Northridge                        Normale
# ...                     ...             ...                            ...
# 1434            Pente douce         Gilbert                        Normale
# 1435            Pente douce  Northwest Ames                        Normale
# 1436            Pente douce        Crawford                        Normale
# 1437            Pente douce      North Ames                        Normale
# 1438            Pente douce         Edwards                        Normale
#
#       ... Qualité de la cuisine Fonctionnalité globale  \
# 0     ...                   Bon                    Typ
# 1     ...                 Moyen                    Typ
# 2     ...                   Bon                    Typ
# 3     ...                   Bon                    Typ
# 4     ...                   Bon                    Typ
# ...   ...                   ...                    ...
# 1434  ...                 Moyen                    Typ
# 1435  ...                 Moyen                   Min1
# 1436  ...                   Bon                    Typ
# 1437  ...                   Bon                    Typ
# 1438  ...                 Moyen                    Typ
#
#                                  Qualité de la cheminée        Type de garage  \
# 0                                       Pas de cheminée   Attaché à la maison
# 1     Moyen - Préfabriquée ou en maçonnerie au sous-sol   Attaché à la maison
# 2     Moyen - Préfabriquée ou en maçonnerie au sous-sol   Attaché à la maison
# 3       Bon - Cheminée en maçonnerie au rez-de-chaussée  Détaché de la maison
# 4     Moyen - Préfabriquée ou en maçonnerie au sous-sol   Attaché à la maison
# ...                                                 ...                   ...
# 1434  Moyen - Préfabriquée ou en maçonnerie au sous-sol   Attaché à la maison
# 1435  Moyen - Préfabriquée ou en maçonnerie au sous-sol   Attaché à la maison
# 1436    Bon - Cheminée en maçonnerie au rez-de-chaussée   Attaché à la maison
# 1437                                    Pas de cheminée   Attaché à la maison
# 1438                                    Pas de cheminée   Attaché à la maison
#
#      Finition intérieure du garage Qualité du garage Allée pavée  \
# 0            Partiellement aménagé             Moyen        Pavé
# 1            Partiellement aménagé             Moyen        Pavé
# 2            Partiellement aménagé             Moyen        Pavé
# 3                      Non aménagé             Moyen        Pavé
# 4            Partiellement aménagé             Moyen        Pavé
# ...                            ...               ...         ...
# 1434         Partiellement aménagé             Moyen        Pavé
# 1435                   Non aménagé             Moyen        Pavé
# 1436         Partiellement aménagé             Moyen        Pavé
# 1437                   Non aménagé             Moyen        Pavé
# 1438                       Aménagé             Moyen        Pavé
#
#      Mois de vente                     Type de vente Condition de la vente
# 0          Février  Acte de garantie - Conventionnel         Vente normale
# 1              Mai  Acte de garantie - Conventionnel         Vente normale
# 2        Septembre  Acte de garantie - Conventionnel         Vente normale
# 3          Février  Acte de garantie - Conventionnel        Vente anormale
# 4         Décembre  Acte de garantie - Conventionnel         Vente normale
# ...            ...                               ...                   ...
# 1434          Août  Acte de garantie - Conventionnel         Vente normale
# 1435       Février  Acte de garantie - Conventionnel         Vente normale
# 1436           Mai  Acte de garantie - Conventionnel         Vente normale
# 1437         Avril  Acte de garantie - Conventionnel         Vente normale
# 1438          Juin  Acte de garantie - Conventionnel         Vente normale
#
# [1439 rows x 41 columns]

# %%
# OverallQual= {
# 10: "Très excellent",
# 9: "Excellent",
# 8: "Très bon",
# 7: "Bon",
# 6: "Au-dessus de la moyenne",
# 5: "Moyenne",
# 4: "En dessous de la moyenne",
# 3: "Médiocre",
# 2: "Mauvais",
# 1: "Très mauvais"
# }"

# %%
""" train_df["OverallQual"] = train_df["OverallQual"].map(OverallQual) """
# Out:
# ' train_df["OverallQual"] = train_df["OverallQual"].map(OverallQual) '

# %%
""" OverallCond= { 
10: "Très excellent",
9: "Excellent",
8: "Très bon",
7: "Bon",
6: "Au-dessus de la moyenne",
5: "Moyenne",
4: "En dessous de la moyenne",
3: "Médiocre",
2: "Mauvais",
1: "Très mauvais"
} """
# Out:
# ' OverallCond= { \n10: "Très excellent",\n9: "Excellent",\n8: "Très bon",\n7: "Bon",\n6: "Au-dessus de la moyenne",\n5: "Moyenne",\n4: "En dessous de la moyenne",\n3: "Médiocre",\n2: "Mauvais",\n1: "Très mauvais"\n} '

# %%
""" train_df["OverallCond"] = train_df["OverallCond"].map(OverallCond) """
# Out:
# ' train_df["OverallCond"] = train_df["OverallCond"].map(OverallCond) '

# %%
""" train_df.OverallQual """
# Out:
# ' train_df.OverallQual '

# %%
""" ode_cols = ['OverallQual','OverallCond','LotShape', 'LandContour','Utilities','LandSlope',  'BsmtQual',  'BsmtFinType1',  'CentralAir',  'Functional', \
           'FireplaceQu', 'GarageFinish', 'GarageQual', 'PavedDrive', 'ExterCond', 'KitchenQual', 'BsmtExposure', 'HeatingQC','ExterQual', 'BsmtCond'] """

ode_cols=['Qualité globale', 'État général', 'Forme du lot', 'Topographie du terrain', 'Services publics disponibles', 
 'Inclinaison du terrain', 'Qualité du sous-sol', 'Type de finition sous-sol (1)', 'Climatisation centrale', 
 'Fonctionnalité globale', 'Qualité de la cheminée', 'Finition intérieure du garage', 'Qualité du garage', 
 'Allée pavée', 'État extérieur', 'Qualité de la cuisine', 'Exposition du sous-sol', 'Qualité du chauffage', 
 'Qualité extérieure', 'État général du sous-sol']

# %%
""" ohe_cols = ['Street', 'LotConfig','Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st', 'Exterior2nd', \
           'MasVnrType','Foundation',  'Electrical',  'SaleType', 'MSZoning', 'SaleCondition', 'Heating', 'GarageType', 'RoofMatl'] """

ohe_cols=['Mois de vente','Type de logement','Type de route', 'Configuration du lot', 'Quartier', 'Proximité (1ère condition)', 'Proximité (2e condition)', 
 'Type de bâtiment', 'Style de maison', 'Style de toit', 'Revêtement extérieur (1)', 'Revêtement extérieur (2)', 
 'Type de parement en maçonnerie', 'Type de fondation', 'Système électrique', 'Type de vente', 
 'Zonage (Classification)', 'Condition de la vente', 'Type de chauffage', 'Type de garage', 'Matériau du toit']

# %%
len(ode_cols)
# Out:
# 20

# %%
len(ohe_cols)
# Out:
# 21

# %%
num_cols = train_df.select_dtypes(include=['int64', 'float64']).columns
num_cols = num_cols.drop('Prix de vente')
num_cols
# Out:
# Index(['Façade (en pieds)', 'Superficie du lot (pieds²)',
#        'Surface de parement (pieds²)', 'Surface non finie sous-sol',
#        'Surface finie basse qualité (pieds²)', 'Chambres (hors sous-sol)',
#        'Cuisines (hors sous-sol)', 'Total des pièces (hors sous-sol)',
#        'Nombre de cheminées', 'Capacité du garage (voitures)',
#        'Surface de la piscine (pieds²)',
#        'Valeur des caractéristiques supplémentaires', 'Âge de la maison',
#        'Rénovation de la maison', 'Surface totale (pieds²)', 'Surface totale',
#        'Total des salles de bain', 'Surface totale des porches (pieds²)'],
#       dtype='object')

# %%
num_pipeline = Pipeline(steps=[
    ('scaler', StandardScaler())
])

# %%
ode_pipeline = Pipeline(steps=[
    ('ode', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

# %%
ohe_pipeline = Pipeline(steps=[
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
col_trans = ColumnTransformer(transformers=[
    ('num_p', num_pipeline, num_cols),
    ('ode_p', ode_pipeline, ode_cols),
    ('ohe_p', ohe_pipeline, ohe_cols),
    ],
    remainder='passthrough', 
    n_jobs=-1)

# %%
pipeline = Pipeline(steps=[
    ('preprocessing', col_trans)
])

# %%
X = train_df.drop('Prix de vente', axis=1)
y = train_df['Prix de vente']

# %%
X_preprocessed = pipeline.fit_transform(X)

# %%
# TRAIN TEST SPLIT

# %%
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=25)

# %%
def get_all_performances(value_train: tuple,
                         values_test: tuple,
                         metrics: list,
                        ) -> pd.DataFrame:
    """ Get all performance metrics listed in `metrics`
    
    Args:
        value_train (tuple): (y_train, y_train_pred)
        values_test (tuple): (y_test, y_test_pred)
        metrics (list): list of metrics to compute
    
    
    Returns:
        pd.DataFrame: column names are: ["metric", "train", "test"]
        
    """
    test_perfs = []
    train_perfs = []
    metric_names = []
    for metric_func in metrics:
        metric_name = metric_func.__name__
        metric_names.append(metric_name)
        train_perfs.append(metric_func(*value_train))
        test_perfs.append(metric_func(*values_test))
    perfs = {"metric": metric_names, "train": train_perfs, "test": test_perfs,}
    return pd.DataFrame(perfs)

# %%
METRICS = [metrics.r2_score,
           metrics.root_mean_squared_error,
           metrics.mean_absolute_percentage_error,
           metrics.max_error,
          ]

# %%
def get_input_features(model_pipeline, cat_step_name=None, ode_step_name=None):
    """
    Récupérer les noms des caractéristiques après transformation dans un pipeline.

    Parameters:
    - model_pipeline : pipeline complet du modèle avec un ColumnTransformer.
    - cat_step_name : nom de l'étape de prétraitement pour les variables catégorielles (optionnel).
    - ode_step_name : nom de l'étape de prétraitement pour les variables ordinales (optionnel).

    Returns:
    - Liste des noms de toutes les caractéristiques après transformation.
    """
    # Accéder au préprocesseur (ColumnTransformer) dans le pipeline
    col_trans = model_pipeline.named_steps['preprocessing']
    
    all_feature_names = []

    # Boucle sur chaque transformer dans le ColumnTransformer
    for step_name, pipe_trans, feat_names in col_trans.transformers_:
        if step_name == cat_step_name:
            # Récupérer les noms des caractéristiques après l'encodage OneHotEncoder
            if 'ohe' in pipe_trans.named_steps:  # Vérifie si le pipeline a un OneHotEncoder
                cat_feature_names = pipe_trans.named_steps['ohe'].get_feature_names_out(input_features=feat_names)
                all_feature_names.extend(cat_feature_names)
        elif step_name == ode_step_name:
            # Récupérer les noms des caractéristiques après l'encodage OrdinalEncoder
            if 'ode' in pipe_trans.named_steps:  # Vérifie si le pipeline a un OrdinalEncoder
                ode_feature_names = pipe_trans.named_steps['ode'].categories_[0]  # Cela renvoie les catégories de l'OrdinalEncoder
                all_feature_names.extend(ode_feature_names)
        else:
            # Ajouter les noms des caractéristiques pour les autres étapes (numériques)
            all_feature_names.extend(feat_names)

    # Retourner tous les noms des caractéristiques
    return all_feature_names

# %%
#build models

# %% [markdown]
# <h1 style="text-align:center;color:yellow;font-size:40px;font-family:ALGERIAN;border:solid">LES MODELES LINEAIRES</h1>

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">LinearRegression</h1>

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr.predict(X_test)

# %%
res_viz = ResidualsPlot(lr,
                        is_fitted="auto",
                        qqplot=True,
                        hist=False,
                        train_color="blue",
                        test_color="red",
                       )
res_viz.fit(X_train, y_train)
res_viz.score(X_test, y_test)
res_viz.show(clear_figure=True);

# %%
# get performances in train & test
perform=get_all_performances(value_train=(y_train, lr.predict(X_train)),
                     values_test=(y_test, lr.predict(X_test)),
                     metrics=METRICS
                    )
perform
# Out:
#                            metric     train          test
# 0                        r2_score  0.935538 -2.773476e+19
# 1         root_mean_squared_error  0.098524  2.093533e+09
# 2  mean_absolute_percentage_error  0.005966  1.646032e+07
# 3                       max_error  0.658614  2.542796e+10

# %%
model_features = get_input_features(pipeline, cat_step_name="ohe_p", ode_step_name="ode_p")
model_features
# Out:
# ['Façade (en pieds)',
#  'Superficie du lot (pieds²)',
#  'Surface de parement (pieds²)',
#  'Surface non finie sous-sol',
#  'Surface finie basse qualité (pieds²)',
#  'Chambres (hors sous-sol)',
#  'Cuisines (hors sous-sol)',
#  'Total des pièces (hors sous-sol)',
#  'Nombre de cheminées',
#  'Capacité du garage (voitures)',
#  'Surface de la piscine (pieds²)',
#  'Valeur des caractéristiques supplémentaires',
#  'Âge de la maison',
#  'Rénovation de la maison',
#  'Surface totale (pieds²)',
#  'Surface totale',
#  'Total des salles de bain',
#  'Surface totale des porches (pieds²)',
#  'Au-dessus de la moyenne',
#  'Bon',
#  'En dessous de la moyenne',
#  'Excellent',
#  'Mauvais',
#  'Moyenne',
#  'Médiocre',
#  'Très bon',
#  'Très excellent',
#  'Très mauvais',
#  'Mois de vente_Août',
#  'Mois de vente_Avril',
#  'Mois de vente_Décembre',
#  'Mois de vente_Février',
#  'Mois de vente_Janvier',
#  'Mois de vente_Juillet',
#  'Mois de vente_Juin',
#  'Mois de vente_Mai',
#  'Mois de vente_Mars',
#  'Mois de vente_Novembre',
#  'Mois de vente_Octobre',
#  'Mois de vente_Septembre',
#  'Type de logement_1 ÉTAGE 1945 ET PLUS ANCIEN',
#  'Type de logement_1 ÉTAGE 1946 ET PLUS RÉCENT - TOUS STYLES',
#  'Type de logement_1 ÉTAGE AVEC GRENIER AMÉNAGÉ - TOUS ÂGES',
#  'Type de logement_1 ÉTAGE ET DEMI - AMÉNAGÉ - TOUS ÂGES',
#  'Type de logement_1 ÉTAGE ET DEMI - NON AMÉNAGÉ - TOUS ÂGES',
#  'Type de logement_1 ÉTAGE PUD (Lotissement planifié) - 1946 ET PLUS RÉCENT',
#  'Type de logement_2 ÉTAGES 1945 ET PLUS ANCIEN',
#  'Type de logement_2 ÉTAGES 1946 ET PLUS RÉCENT',
#  'Type de logement_2 ÉTAGES ET DEMI - TOUS ÂGES',
#  'Type de logement_2 ÉTAGES PUD - 1946 ET PLUS RÉCENT',
#  'Type de logement_CONVERSION 2 FAMILLES - TOUS STYLES ET ÂGES',
#  'Type de logement_DUPLEX - TOUS STYLES ET ÂGES',
#  'Type de logement_FOYER DIVISÉ',
#  'Type de logement_NIVEAUX MULTIPLES OU PARTIELS',
#  'Type de logement_PUD MULTI-NIVEAUX - INCLUT NIVEAUX DIVISÉS',
#  'Type de route_Gravier',
#  'Type de route_Pavé',
#  'Configuration du lot_Cul-de-sac',
#  'Configuration du lot_Double façade',
#  "Configuration du lot_Lot d'angle",
#  'Configuration du lot_Lot intérieur',
#  'Configuration du lot_Triple façade',
#  'Quartier_Bloomington Heights',
#  'Quartier_Bluestem',
#  'Quartier_Briardale',
#  'Quartier_Brookside',
#  'Quartier_Clear Creek',
#  'Quartier_College Creek',
#  'Quartier_Crawford',
#  'Quartier_Edwards',
#  'Quartier_Gilbert',
#  'Quartier_Iowa DOT et chemin de fer',
#  'Quartier_Meadow Village',
#  'Quartier_Mitchell',
#  'Quartier_North Ames',
#  'Quartier_Northpark Villa',
#  'Quartier_Northridge',
#  'Quartier_Northridge Heights',
#  'Quartier_Northwest Ames',
#  'Quartier_Sawyer',
#  'Quartier_Sawyer Ouest',
#  'Quartier_Somerset',
#  'Quartier_Stone Brook',
#  "Quartier_Sud et Ouest de l'Université d'État de l'Iowa",
#  'Quartier_Timberland',
#  'Quartier_Veenker',
#  'Quartier_Vieille Ville',
#  'Proximité (1ère condition)_Adjacente à un espace vert ou parc',
#  'Proximité (1ère condition)_Adjacente à une voie ferrée est-ouest',
#  'Proximité (1ère condition)_Adjacente à une voie ferrée nord-sud',
#  'Proximité (1ère condition)_Normale',
#  "Proximité (1ère condition)_Proche d'un espace vert ou parc",
#  "Proximité (1ère condition)_Proche d'une artère principale",
#  "Proximité (1ère condition)_Proche d'une route secondaire",
#  "Proximité (1ère condition)_À moins de 200 pieds d'une voie ferrée est-ouest",
#  "Proximité (1ère condition)_À moins de 200 pieds d'une voie ferrée nord-sud",
#  'Proximité (2e condition)_Adjacente à un espace vert ou parc',
#  'Proximité (2e condition)_Adjacente à une voie ferrée est-ouest',
#  'Proximité (2e condition)_Adjacente à une voie ferrée nord-sud',
#  'Proximité (2e condition)_Normale',
#  "Proximité (2e condition)_Proche d'un espace vert ou parc",
#  "Proximité (2e condition)_Proche d'une artère principale",
#  "Proximité (2e condition)_Proche d'une route secondaire",
#  "Proximité (2e condition)_À moins de 200 pieds d'une voie ferrée nord-sud",
#  'Type de bâtiment_Conversion deux familles',
#  'Type de bâtiment_Duplex',
#  'Type de bâtiment_Maison de ville (bout)',
#  'Type de bâtiment_Maison de ville (intérieur)',
#  'Type de bâtiment_Maison individuelle',
#  'Style de maison_Deux étages',
#  'Style de maison_Deux étages et demi, aménagé',
#  'Style de maison_Deux étages et demi, non aménagé',
#  'Style de maison_Foyer divisé',
#  'Style de maison_Niveaux divisés',
#  'Style de maison_Un étage',
#  'Style de maison_Un étage et demi, aménagé',
#  'Style de maison_Un étage et demi, non aménagé',
#  'Style de toit_Abri',
#  'Style de toit_Gabriel (grange)',
#  'Style de toit_Mansardé',
#  'Style de toit_Pente',
#  'Style de toit_Pignon',
#  'Style de toit_Plat',
#  'Revêtement extérieur (1)_Bardeaux en amiante',
#  'Revêtement extérieur (1)_Bardeaux en asphalte',
#  'Revêtement extérieur (1)_Bardeaux en bois',
#  'Revêtement extérieur (1)_Bloc de béton',
#  'Revêtement extérieur (1)_Brique apparente',
#  'Revêtement extérieur (1)_Brique commune',
#  'Revêtement extérieur (1)_Contreplaqué',
#  'Revêtement extérieur (1)_Panneau de ciment',
#  'Revêtement extérieur (1)_Panneau dur',
#  'Revêtement extérieur (1)_Pierre',
#  'Revêtement extérieur (1)_Revêtement en bois',
#  'Revêtement extérieur (1)_Revêtement en vinyle',
#  'Revêtement extérieur (1)_Revêtement métallique',
#  'Revêtement extérieur (1)_Stuc',
#  'Revêtement extérieur (1)_Stuc imitation',
#  'Revêtement extérieur (2)_Autre',
#  'Revêtement extérieur (2)_Bardeaux en amiante',
#  'Revêtement extérieur (2)_Bardeaux en asphalte',
#  'Revêtement extérieur (2)_Bardeaux en bois',
#  'Revêtement extérieur (2)_Bloc de béton',
#  'Revêtement extérieur (2)_Brique apparente',
#  'Revêtement extérieur (2)_Brique commune',
#  'Revêtement extérieur (2)_Contreplaqué',
#  'Revêtement extérieur (2)_Panneau de ciment',
#  'Revêtement extérieur (2)_Panneau dur',
#  'Revêtement extérieur (2)_Pierre',
#  'Revêtement extérieur (2)_Revêtement en bois',
#  'Revêtement extérieur (2)_Revêtement en vinyle',
#  'Revêtement extérieur (2)_Revêtement métallique',
#  'Revêtement extérieur (2)_Stuc',
#  'Revêtement extérieur (2)_Stuc imitation',
#  'Type de parement en maçonnerie_Aucune',
#  'Type de parement en maçonnerie_Briques communes',
#  'Type de parement en maçonnerie_Briques en façade',
#  'Type de parement en maçonnerie_Pierre',
#  'Type de fondation_BrkTil',
#  'Type de fondation_CBlock',
#  'Type de fondation_PConc',
#  'Type de fondation_Slab',
#  'Type de fondation_Stone',
#  'Type de fondation_Wood',
#  'Système électrique_Disjoncteurs',
#  'Système électrique_Fusibles',
#  'Système électrique_Fusibles anciens',
#  'Système électrique_Fusibles et câblage de mauvaise qualité',
#  'Système électrique_Mixte',
#  'Type de vente_Acte de garantie - Conventionnel',
#  'Type de vente_Acte de garantie - Espèces',
#  "Type de vente_Acte de l'officier judiciaire/Etat",
#  'Type de vente_Autre',
#  'Type de vente_Contrat - 15% acompte, conditions normales',
#  'Type de vente_Contrat - Acompte faible',
#  "Type de vente_Contrat - Acompte faible et faible taux d'intérêt",
#  "Type de vente_Contrat - Faible taux d'intérêt",
#  'Type de vente_Maison neuve construite et vendue',
#  'Zonage (Classification)_Commercial',
#  'Zonage (Classification)_Résidentiel basse densité',
#  'Zonage (Classification)_Résidentiel densité moyenne',
#  'Zonage (Classification)_Résidentiel flottant',
#  'Zonage (Classification)_Résidentiel haute densité',
#  'Condition de la vente_Achat terrain adjoint',
#  'Condition de la vente_Allocation (propriétés liées)',
#  'Condition de la vente_Maison incomplète',
#  'Condition de la vente_Vente anormale',
#  'Condition de la vente_Vente entre membres de la famille',
#  'Condition de la vente_Vente normale',
#  'Type de chauffage_Chauffage mural',
#  'Type de chauffage_Chauffage par le sol',
#  'Type de chauffage_Chauffage à eau chaude ou vapeur (autre que gaz)',
#  'Type de chauffage_Chauffage à gaz',
#  'Type de chauffage_Chauffage à gaz (chaudière)',
#  'Type de chauffage_Gravité',
#  'Type de garage_Abris voiture',
#  'Type de garage_Attaché à la maison',
#  'Type de garage_Détaché de la maison',
#  'Type de garage_Garage au sous-sol',
#  'Type de garage_Garage intégré (fait partie de la maison, souvent avec une pièce au-dessus)',
#  'Type de garage_Pas de garage',
#  "Type de garage_Plus d'un type de garage",
#  'Matériau du toit_Bardeau composite standard',
#  'Matériau du toit_Bardeau de bois',
#  'Matériau du toit_Bardeau en bois',
#  'Matériau du toit_Gravier et bitume',
#  'Matériau du toit_Membrane',
#  'Matériau du toit_Métal',
#  'Matériau du toit_Rouleau']

# %%
#df_feature_importance = pd.DataFrame(
#    lr.coef_, 
#    columns=["coef"],
#    index=model_features # Les noms des caractéristiques
#)

#df_feature_importance.head()

# %%
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/lr_performance.pkl")
# Out:
# ['../Ressources/performance/lr_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">Ridge</h1>

# %%
ridge = Ridge()

# %%
param_grid_ridge = {
    'alpha': [0.05, 0.1, 1, 3, 5, 10],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag']
}

# %%
ridge_cv = GridSearchCV(ridge, param_grid_ridge, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [0.05, 0.1, 1, 3, 5, 10],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag']},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * ridge_cv.best_score_)
# Out:
# 0.12035111614034434

# %%
perform=get_all_performances(value_train=(y_train, ridge_cv.predict(X_train)),
                     values_test=(y_test, ridge_cv.predict(X_test)),
                     metrics=METRICS
                    )
perform
# Out:
#                            metric     train      test
# 0                        r2_score  0.930479  0.875533
# 1         root_mean_squared_error  0.102317  0.140247
# 2  mean_absolute_percentage_error  0.006254  0.007882
# 3                       max_error  0.669982  0.879807

# %%
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/ridge_cv_performance.pkl")
# Out:
# ['../Ressources/performance/ridge_cv_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">Lasso</h1>

# %%
Lasso = Lasso()

# %%
param_grid_Lasso = {
    'alpha': [0.05, 0.1, 1, 3, 5, 10]
}

# %%
Lasso_cv = GridSearchCV(Lasso, param_grid_Lasso, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
Lasso_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(), n_jobs=-1,
#              param_grid={'alpha': [0.05, 0.1, 1, 3, 5, 10]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * Lasso_cv.best_score_)
# Out:
# 0.16595283185877152

# %%
perform=get_all_performances(value_train=(y_train, Lasso_cv.predict(X_train)),
                     values_test=(y_test, Lasso_cv.predict(X_test)),
                     metrics=METRICS
                    )
perform
# Out:
#                            metric     train      test
# 0                        r2_score  0.823435  0.790138
# 1         root_mean_squared_error  0.163058  0.182110
# 2  mean_absolute_percentage_error  0.009822  0.010682
# 3                       max_error  0.938445  1.009648

# %%
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/Lasso_cv_performance.pkl")
# Out:
# ['../Ressources/performance/Lasso_cv_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">Elasticnet</h1>

# %%
ElasticNet = ElasticNet()

# %%
param_grid_ElasticNet = {
    'alpha': [0.05, 0.1, 1, 3, 5, 10],
    'l1_ratio': [0.1, 0.5, 0.9, 1]
}

# %%
ElasticNet_cv = GridSearchCV(ElasticNet, param_grid_ElasticNet, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
ElasticNet_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=ElasticNet(), n_jobs=-1,
#              param_grid={'alpha': [0.05, 0.1, 1, 3, 5, 10],
#                          'l1_ratio': [0.1, 0.5, 0.9, 1]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * ElasticNet_cv.best_score_)
# Out:
# 0.13682083430827968

# %%
perform=get_all_performances(value_train=(y_train, ElasticNet_cv.predict(X_train)),
                     values_test=(y_test, ElasticNet_cv.predict(X_test)),
                     metrics=METRICS
                    )
perform
# Out:
#                            metric     train      test
# 0                        r2_score  0.883497  0.860537
# 1         root_mean_squared_error  0.132451  0.148456
# 2  mean_absolute_percentage_error  0.007996  0.008450
# 3                       max_error  0.839135  0.943264

# %%
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/ElasticNet_cv_performance.pkl")
# Out:
# ['../Ressources/performance/ElasticNet_cv_performance.pkl']

# %% [markdown]
# > LE MODELE DE RIDGE EST PERFORMANT EN TERME DE R2
#
# > LE MODELE DE RIDGE EST PERFORMANT EN TERME DE RMSE
#
# > LE MODELE DE RIDGE EST PERFORMANT EN TERME DE MAE
#
# > LE MODELE DE RIDGE EST PERFORMANT EN TERME DE MAPE

# %% [markdown]
# <h1 style="text-align:center;color:yellow;font-size:40px;font-family:ALGERIAN;border:solid">LES MODELES NON LINEAIRES</h1>

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">RandomForestRegressor</h1>

# %%
RFR = RandomForestRegressor(random_state=13)

# %%
param_grid_RFR = {
    'max_depth': [5, 10, 15],
    'n_estimators': [100, 250, 500],
    'min_samples_split': [3, 5, 10]
}

# %%
rfr_cv = GridSearchCV(RFR, param_grid_RFR, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
rfr_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=13), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15],
#                          'min_samples_split': [3, 5, 10],
#                          'n_estimators': [100, 250, 500]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * rfr_cv.best_score_)
# Out:
# 0.13672171953829854

# %%
rfr_cv.best_params_
# Out:
# {'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 500}

# %%
# get performances in train & test
perform=get_all_performances(value_train=(y_train, rfr_cv.predict(X_train)),
                     values_test=(y_test, rfr_cv.predict(X_test)),
                     metrics=METRICS
                    )
perform
# Out:
#                            metric     train      test
# 0                        r2_score  0.982305  0.860574
# 1         root_mean_squared_error  0.051619  0.148436
# 2  mean_absolute_percentage_error  0.003028  0.008159
# 3                       max_error  0.339188  0.915770

# %%
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/rfr_cv_performance.pkl")
# Out:
# ['../Ressources/performance/rfr_cv_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">XGBRegressor</h1>

# %%
XGB = XGBRegressor(random_state=13)

# %%
param_grid_XGB = {
    'learning_rate': [0.05, 0.1, 0.2],
    'n_estimators': [300],
    'max_depth': [3],
    'min_child_weight': [1,2,3],
    'gamma': [0, 0.1, 0.2],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
}

# %%
xgb_cv = GridSearchCV(XGB, param_grid_XGB, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
xgb_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=13, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'gamma': [0, 0.1, 0.2],
#                          'learning_rate': [0.05, 0.1, 0.2], 'max_depth': [3],
#                          'min_child_weight': [1, 2, 3], 'n_estimators': [300],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * xgb_cv.best_score_)
# Out:
# 0.12203194054532636

# %%
perform=get_all_performances(value_train=(y_train, xgb_cv.predict(X_train)),
                     values_test=(y_test, xgb_cv.predict(X_test)),
                     metrics=METRICS
                    )
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/xgb_cv_performance.pkl")
# Out:
# ['../Ressources/performance/xgb_cv_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">GradientBoostingRegressor</h1>

# %%
GBR = GradientBoostingRegressor()

# %%
param_grid_GBR = {
    'max_depth': [12, 15, 20],
    'n_estimators': [200, 300, 1000],
    'min_samples_leaf': [10, 25, 50],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_features': [0.01, 0.1, 0.7]
}

# %%
GBR_cv = GridSearchCV(GBR, param_grid_GBR, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
GBR_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [12, 15, 20],
#                          'max_features': [0.01, 0.1, 0.7],
#                          'min_samples_leaf': [10, 25, 50],
#                          'n_estimators': [200, 300, 1000]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * GBR_cv.best_score_)
# Out:
# 0.1188855954425865

# %%
perform=get_all_performances(value_train=(y_train, GBR_cv.predict(X_train)),
                     values_test=(y_test, GBR_cv.predict(X_test)),
                     metrics=METRICS
                    )
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/GBR_cv_performance.pkl")
# Out:
# ['../Ressources/performance/GBR_cv_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">LGBMRegressor</h1>

# %%
lgbm_regressor = lgb.LGBMRegressor()

# %%
param_grid_lgbm = {
    'boosting_type': ['gbdt', 'dart'],
    'num_leaves': [20, 30, 40],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 300]
}

# %%
lgbm_cv = GridSearchCV(lgbm_regressor, param_grid_lgbm, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
lgbm_cv.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002465 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2007
# [LightGBM] [Info] Number of data points in the train set: 1151, number of used features: 132
# [LightGBM] [Info] Start training from score 12.023259
# GridSearchCV(cv=3, estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'boosting_type': ['gbdt', 'dart'],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'n_estimators': [100, 200, 300],
#                          'num_leaves': [20, 30, 40]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * lgbm_cv.best_score_)
# Out:
# 0.13104024978735038

# %%
perform=get_all_performances(value_train=(y_train, lgbm_cv.predict(X_train)),
                     values_test=(y_test, lgbm_cv.predict(X_test)),
                     metrics=METRICS
                    )
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/lgbm_cv_performance.pkl")
# Out:
# ['../Ressources/performance/lgbm_cv_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">CatBoostRegressor</h1>

# %%
catboost = CatBoostRegressor(loss_function='RMSE', verbose=False)

# %%
param_grid_cat ={
    'iterations': [100, 500, 1000],
    'depth': [4, 6, 8, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.5]
}

# %%
cat_cv = GridSearchCV(catboost, param_grid_cat, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
cat_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostRegressor object at 0x0000014762244800>,
#              n_jobs=-1,
#              param_grid={'depth': [4, 6, 8, 10], 'iterations': [100, 500, 1000],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.5]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * cat_cv.best_score_)
# Out:
# 0.11881150814124826

# %%
perform=get_all_performances(value_train=(y_train, cat_cv.predict(X_train)),
                     values_test=(y_test, cat_cv.predict(X_test)),
                     metrics=METRICS
                    )
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/cat_cv_performance.pkl")
# Out:
# ['../Ressources/performance/cat_cv_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">VotingRegressor</h1>

# %%
vr = VotingRegressor([('gbr', GBR_cv.best_estimator_),
                      ('xgb', xgb_cv.best_estimator_),
                      ('ridge', ridge_cv.best_estimator_)],
                    weights=[2,3,1])

# %%
vr.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('gbr',
#                              GradientBoostingRegressor(learning_rate=0.01,
#                                                        max_depth=12,
#                                                        max_features=0.1,
#                                                        min_samples_leaf=10,
#                                                        n_estimators=1000)),
#                             ('xgb',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=0.9, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_m...
#                                           interaction_constraints=None,
#                                           learning_rate=0.05, max_bin=None,
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=3,
#                                           max_leaves=None, min_child_weight=2,
#                                           missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None, n_estimators=300,
#                                           n_jobs=None, num_parallel_tree=None,
#                                           random_state=13, ...)),
#                             ('ridge', Ridge(alpha=5, solver='sag'))],
#                 weights=[2, 3, 1])

# %%
y_pred_vr = vr.predict(X_test)

# %%
metrics.root_mean_squared_error(y_test, y_pred_vr)
# Out:
# 0.12663024966223516

# %%
perform=get_all_performances(value_train=(y_train, vr.predict(X_train)),
                     values_test=(y_test, vr.predict(X_test)),
                     metrics=METRICS
                    )
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/vr_performance.pkl")
# Out:
# ['../Ressources/performance/vr_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:green;font-size:30px;font-family:ALGERIAN;border:solid">StackingRegressor</h1>

# %%
estimators = [
    ('gbr', GBR_cv.best_estimator_),
    ('xgb', xgb_cv.best_estimator_),
    ('cat', cat_cv.best_estimator_),
    ('lgb', lgbm_cv.best_estimator_),
    ('rfr', rfr_cv.best_estimator_),
]

# %%
stackreg = StackingRegressor(
            estimators = estimators,
            final_estimator = vr
)

# %%
stackreg.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003291 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2007
# [LightGBM] [Info] Number of data points in the train set: 1151, number of used features: 132
# [LightGBM] [Info] Start training from score 12.023259
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1906
# [LightGBM] [Info] Number of data points in the train set: 920, number of used features: 125
# [LightGBM] [Info] Start training from score 12.032469
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001585 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1897
# [LightGBM] [Info] Number of data points in the train set: 921, number of used features: 127
# [LightGBM] [Info] Start training from score 12.018337
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001198 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1905
# [LightGBM] [Info] Number of data points in the train set: 921, number of used features: 127
# [LightGBM] [Info] Start training from score 12.020647
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001831 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1896
# [LightGBM] [Info] Number of data points in the train set: 921, number of used features: 127
# [LightGBM] [Info] Start training from score 12.021127
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001951 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1899
# [LightGBM] [Info] Number of data points in the train set: 921, number of used features: 128
# [LightGBM] [Info] Start training from score 12.023724
# StackingRegressor(estimators=[('gbr',
#                                GradientBoostingRegressor(learning_rate=0.01,
#                                                          max_depth=12,
#                                                          max_features=0.1,
#                                                          min_samples_leaf=10,
#                                                          n_estimators=1000)),
#                               ('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.9, device=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval...
#                                                                             interaction_constraints=None,
#                                                                             learning_rate=0.05,
#                                                                             max_bin=None,
#                                                                             max_cat_threshold=None,
#                                                                             max_cat_to_onehot=None,
#                                                                             max_delta_step=None,
#                                                                             max_depth=3,
#                                                                             max_leaves=None,
#                                                                             min_child_weight=2,
#                                                                             missing=nan,
#                                                                             monotone_constraints=None,
#                                                                             multi_strategy=None,
#                                                                             n_estimators=300,
#                                                                             n_jobs=None,
#                                                                             num_parallel_tree=None,
#                                                                             random_state=13, ...)),
#                                                               ('ridge',
#                                                                Ridge(alpha=5,
#                                                                      solver='sag'))],
#                                                   weights=[2, 3, 1]))

# %%
y_pred_stack = stackreg.predict(X_test)

# %%
metrics.root_mean_squared_error(y_test, y_pred_stack)
# Out:
# 0.12787636150659354

# %%
perform=get_all_performances(value_train=(y_train, stackreg.predict(X_train)),
                     values_test=(y_test, stackreg.predict(X_test)),
                     metrics=METRICS
                    )
# Sauvegarder dans un fichier
joblib.dump(perform, "../Ressources/performance/stackreg_performance.pkl")
# Out:
# ['../Ressources/performance/stackreg_performance.pkl']

# %% [markdown]
# <h1 style="text-align:center;color:yellow;font-size:50px;font-family:ALGERIAN;border:solid">ENREGISTREMENT DU MODELE FINAL</h1>

# %%
import joblib

joblib.dump(ridge_cv, '../Ressources/modele_final/ridge_model.pkl')
joblib.dump(pipeline, '../Ressources/pipeline/pipeline.pkl')
joblib.dump(cat_cv,'../Ressources/modele_final/ridge_model.pkl')
# Out:
# ['../Ressources/pipeline/pipeline.pkl']
